# %% [markdown]
# <a href="https://colab.research.google.com/github/MadagoniRishitha/Rishitha-ANDintern/blob/main/heart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
count_1 = df['Sex'].value_counts()
persent_1 = df['Sex'].value_counts(normalize=True)*100
freq_table_1 = pd.DataFrame({'Frequancy':count_1 , 'Persentag':persent_1})

freq_table_1
# Out:
#      Frequancy  Persentag
# Sex
# M          725  78.976035
# F          193  21.023965

# %%
count_2 = df['ChestPainType'].value_counts()
persent_2 = df['ChestPainType'].value_counts(normalize=True)*100
freq_table_2 = pd.DataFrame({'Frequancy':count_2 , 'Persentag':persent_2})

freq_table_2
# Out:
#                Frequancy  Persentag
# ChestPainType
# ASY                  496  54.030501
# NAP                  203  22.113290
# ATA                  173  18.845316
# TA                    46   5.010893

# %%
count_3 = df['FastingBS'].value_counts()
persent_3 = df['FastingBS'].value_counts(normalize=True)*100
freq_table_3 = pd.DataFrame({'Frequancy':count_3 , 'Persentag':persent_3})

freq_table_3
# Out:
#            Frequancy  Persentag
# FastingBS
# 0                704  76.688453
# 1                214  23.311547

# %%
count_4 = df['RestingECG'].value_counts()
persent_4 = df['RestingECG'].value_counts(normalize=True)*100
freq_table_4 = pd.DataFrame({'Frequancy':count_4 , 'Persentag':persent_4})

freq_table_4
# Out:
#             Frequancy  Persentag
# RestingECG
# Normal            552  60.130719
# LVH               188  20.479303
# ST                178  19.389978

# %%
count_5 = df['ExerciseAngina'].value_counts()
persent_5 = df['ExerciseAngina'].value_counts(normalize=True)*100
freq_table_5 = pd.DataFrame({'Frequancy':count_5 , 'Persentag':persent_5})

freq_table_5
# Out:
#                 Frequancy  Persentag
# ExerciseAngina
# N                     547  59.586057
# Y                     371  40.413943

# %%
count_6 = df['ST_Slope'].value_counts()
persent_6 = df['ST_Slope'].value_counts(normalize=True)*100
freq_table_6 = pd.DataFrame({'Frequancy':count_6 , 'Persentag':persent_6})

freq_table_6
# Out:
#           Frequancy  Persentag
# ST_Slope
# Flat            460  50.108932
# Up              395  43.028322
# Down             63   6.862745

# %%
count_7 = df['HeartDisease'].value_counts()
persent_7 = df['HeartDisease'].value_counts(normalize=True)*100
freq_table_7 = pd.DataFrame({'Frequancy':count_7 , 'Persentag':persent_7})

freq_table_7
# Out:
#               Frequancy  Persentag
# HeartDisease
# 1                   508  55.337691
# 0                   410  44.662309

# %%
count_1.plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
count_1.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
count_2.plot(kind='bar')
# Out:
# <Axes: xlabel='ChestPainType'>

# %%
count_2.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
count_3.plot(kind='bar')
# Out:
# <Axes: xlabel='FastingBS'>

# %%
count_3.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
count_4.plot(kind='bar')
# Out:
# <Axes: xlabel='RestingECG'>

# %%
count_4.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
count_5.plot(kind='bar')
# Out:
# <Axes: xlabel='ExerciseAngina'>

# %%
count_5.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
count_6.plot(kind='bar')
# Out:
# <Axes: xlabel='ST_Slope'>

# %%
count_6.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
count_7.plot(kind='bar')
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
count_7.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['RestingBP'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['RestingBP'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Cholesterol'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Cholesterol'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['MaxHR'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['MaxHR'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Oldpeak'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Oldpeak'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.describe(include='all')
# Out:
#                Age  Sex ChestPainType   RestingBP  Cholesterol   FastingBS  \
# count   918.000000  918           918  918.000000   918.000000  918.000000
# unique         NaN    2             4         NaN          NaN         NaN
# top            NaN    M           ASY         NaN          NaN         NaN
# freq           NaN  725           496         NaN          NaN         NaN
# mean     53.510893  NaN           NaN  132.396514   198.799564    0.233115
# std       9.432617  NaN           NaN   18.514154   109.384145    0.423046
# min      28.000000  NaN           NaN    0.000000     0.000000    0.000000
# 25%      47.000000  NaN           NaN  120.000000   173.250000    0.000000
# 50%      54.000000  NaN           NaN  130.000000   223.000000    0.000000
# 75%      60.000000  NaN           NaN  140.000000   267.000000    0.000000
# max      77.000000  NaN           NaN  200.000000   603.000000    1.000000
#
#        RestingECG       MaxHR ExerciseAngina     Oldpeak ST_Slope  \
# ...

# %%
x = df.groupby(['Sex'])['Cholesterol'].mean()
x.plot(kind='pie')
pd.DataFrame(x)
# Out:
#      Cholesterol
# Sex
# F     241.196891
# M     187.513103

# %%
y = df.groupby(['ChestPainType'])['Age'].mean()
y.plot(kind='pie')
pd.DataFrame(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-067850b5eddc> in <cell line: 1>()
# ----> 1 y = df.groupby(['ChestPainType'])['Age'].mean()
#       2 y.plot(kind='pie')
#       3 pd.DataFrame(y)
#
# NameError: name 'df' is not defined

# %%
z = df.groupby(['Sex','RestingECG'])['ExerciseAngina'].value_counts()
z.plot(kind='bar')
pd.DataFrame(z)
# Out:
#                                count
# Sex RestingECG ExerciseAngina
# F   LVH        N                  36
#                Y                  11
#     Normal     N                  93
#                Y                  25
#     ST         N                  21
#                Y                   7
# M   LVH        N                  79
#                Y                  62
#     Normal     N                 252
#                Y                 182
#     ST         Y                  84
#                N                  66

# %%
l = df.groupby(['Age','ExerciseAngina'])['Oldpeak'].mean()
l.plot(kind='kde')
pd.DataFrame(l)
# Out:
#                     Oldpeak
# Age ExerciseAngina
# 28  N                 0.000
# 29  N                 0.000
# 30  N                 0.000
# 31  N                 0.000
#     Y                 1.500
# ...                     ...
# 74  Y                 1.875
# 75  N                 0.000
#     Y                 2.500
# 76  N                 2.300
# 77  Y                 1.000
#
# [92 rows x 1 columns]

# %%
m = df.groupby(['Age'])['HeartDisease'].mean()
m.plot(kind='kde')
pd.DataFrame(m)
# Out:
#      HeartDisease
# Age
# 28       0.000000
# 29       0.000000
# 30       0.000000
# 31       0.500000
# 32       0.400000
# 33       0.500000
# 34       0.285714
# 35       0.363636
# 36       0.333333
# 37       0.090909
# 38       0.687500
# 39       0.133333
# 40       0.461538
# 41       0.250000
# 42       0.166667
# 43       0.458333
# 44       0.315789
# 45       0.166667
# 46       0.541667
# 47       0.578947
# 48       0.483871
# 49       0.523810
# 50       0.560000
# 51       0.428571
# 52       0.527778
# 53       0.454545
# 54       0.450980
# 55       0.585366
# 56       0.657895
# 57       0.684211
# 58       0.666667
# 59       0.657143
# 60       0.750000
# 61       0.838710
# 62       0.714286
# 63       0.766667
# 64       0.681818
# 65       0.714286
# 66       0.538462
# 67       0.800000
# 68       0.600000
# 69       0.769231
# 70       0.857143
# 71       0.400000
# 72       0.750000
# 73       1.000000
# 74       0.714286
# 75       0.666667
# ...
